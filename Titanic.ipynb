# %% [markdown]
# <a href="https://colab.research.google.com/github/katerina2901/data_solar/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Введение

# %% [markdown]
# ## 1.4

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/titanic.csv')

# %%
data.head(7)
data.iloc[7]
data.iloc[:7]
data.loc[:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 1.5 Задача фильтрации

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.rename(columns = {'math score' : 'math_score', 'reading score' : 'reading_score', 'writing score' : 'writing_score', 'parental level of education': 'parental_level_of_education '}, inplace = True)

# %%
df.gender == 'female'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997     True
# 998     True
# 999     True
# Name: gender, Length: 1000, dtype: bool

# %%
df.gender.loc[df.gender == 'female']
# Out:
# 0      female
# 1      female
# 2      female
# 5      female
# 6      female
#         ...
# 993    female
# 995    female
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 518, dtype: object

# %%
df.writing_score.mean()
# Out:
# 68.054

# %%
df.loc[df.writing_score > df.writing_score.mean()]
# Out:
#      gender race/ethnicity parental_level_of_education          lunch  \
# 0    female        group B            bachelor's degree      standard
# 1    female        group C                 some college      standard
# 2    female        group B              master's degree      standard
# 4      male        group C                 some college      standard
# 5    female        group B           associate's degree      standard
# ..      ...            ...                          ...           ...
# 992  female        group D           associate's degree  free/reduced
# 993  female        group D            bachelor's degree  free/reduced
# 995  female        group E              master's degree      standard
# 998  female        group D                 some college      standard
# 999  female        group D                 some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score
# ...

# %%
df[(df.writing_score > 99) & (df.gender == 'female')]
# Out:
#      gender race/ethnicity parental_level_of_education          lunch  \
# 106  female        group D              master's degree      standard
# 114  female        group E            bachelor's degree      standard
# 165  female        group C            bachelor's degree      standard
# 179  female        group D             some high school      standard
# 377  female        group D              master's degree  free/reduced
# 403  female        group D                  high school      standard
# 458  female        group E            bachelor's degree      standard
# 566  female        group E            bachelor's degree  free/reduced
# 685  female        group E              master's degree      standard
# 903  female        group D            bachelor's degree  free/reduced
# 957  female        group D              master's degree      standard
# 962  female        group E           associate's degree      standard
# ...

# %%
df.query('(gender == "male") and (lunch == "standard") and (math_score > 76)')
# Out:
#     gender race/ethnicity parental_level_of_education      lunch  \
# 13    male        group A                 some college  standard
# 16    male        group C                  high school  standard
# 34    male        group E                 some college  standard
# 35    male        group E           associate's degree  standard
# 49    male        group C                  high school  standard
# ..     ...            ...                          ...       ...
# 956   male        group C                 some college  standard
# 971   male        group C             some high school  standard
# 981   male        group D             some high school  standard
# 982   male        group B             some high school  standard
# 987   male        group E             some high school  standard
#
#     test preparation course  math_score  reading_score  writing_score
# 13                completed          78             72             70
# ...

# %%
df.query('lunch == "free/reduced"')[['math_score','reading_score', 'writing_score']].describe().T
# Out:
#                count       mean        std   min   25%   50%   75%    max
# math_score     355.0  58.921127  15.159956   0.0  49.0  60.0  69.0  100.0
# reading_score  355.0  64.653521  14.895339  17.0  56.0  65.0  75.0  100.0
# writing_score  355.0  63.022535  15.433823  10.0  53.0  64.0  74.0  100.0

# %%
df.query('lunch != "free/reduced"')[['math_score','reading_score', 'writing_score']].describe().T
# Out:
#                count       mean        std   min   25%   50%   75%    max
# math_score     645.0  70.034109  13.653501  19.0  61.0  69.0  80.0  100.0
# reading_score  645.0  71.654264  13.830602  26.0  63.0  72.0  82.0  100.0
# writing_score  645.0  70.823256  14.339487  22.0  62.0  72.0  81.0  100.0

# %%
df.lunch.loc[df.lunch == 'free/reduced']
# Out:
# 3      free/reduced
# 7      free/reduced
# 8      free/reduced
# 9      free/reduced
# 17     free/reduced
#            ...
# 992    free/reduced
# 993    free/reduced
# 996    free/reduced
# 997    free/reduced
# 999    free/reduced
# Name: lunch, Length: 355, dtype: object

# %%
df[['math_score', 'reading_score']].head()
# Out:
#    math_score  reading_score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %%
score_columd = [i for i in list(df) if 'score' in i]

# %%
df.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
data = pd.read_csv('/content/column_hell.csv')

# %%
selected_columns = data.filter(like='-')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %%
data.columns
# Out:
# Index(['yrh&6', 'ohku', 'q', 'hfxx', 'umeca-4', 'apj', 'g', 'ijvnixxo',
#        'kudbpyw-3', 'upubjv', 'njgmxlb', 'inobdsicl&9', 'mqm', 'ydbtkyghp',
#        'umeca', 'dhcy', 'tif&3', 'qo', 'mrhhq%4', 'wvefah', 'sladymzr#0',
#        'fla%8', 'y', 'g-3', 'apjtyqpk', 'epwurk#5', 'cmcj_7', 'inobdsicl',
#        'qo&1', 'gmdegafzs', 'hwtbyrkp', 'yrh', 'bv&6', 'kcksar', 'v-9',
#        'xzmnhsaq', 'kudbpyw', 'lv', 'fla-6', 'z', 'yv', 'epwurk', 'v', 'bv',
#        'fla', 'rqb', 'njgmxlb:8', 'z_7', 'cglh', 'fla#4', 'cenir', 'cmcj',
#        'mrhhq', 'jo', 'y$1', 'xiouy', 'umeca&6', 'hwtbyrkp-5', 'qo_9', 'fflgn',
#        'gmdegafzs&7', 'udwjruv', 'quihccw', 'qneupdcig', 'atbb', 'fi',
#        'clsruyy', 'g&6', 'qo$6', 'ap', 'o', 'sladymzr', 'tif', 'wuikzxt',
#        'wzuvc'],
#       dtype='object')

# %% [markdown]
# ## 1.6 Группировка и агрегация

# %%
df.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
mean_scores = df.groupby(['gender', 'race/ethnicity'], as_index=False).aggregate({'math_score': 'mean', 'reading_score': 'mean'}).rename(columns = {'math_score': 'mean_math_score', 'reading_score': 'mean_reading_score'})

# %%
mean_scores
# Out:
#    gender race/ethnicity  mean_math_score  mean_reading_score
# 0  female        group A        58.527778           69.000000
# 1  female        group B        61.403846           71.076923
# 2  female        group C        62.033333           71.944444
# 3  female        group D        65.248062           74.046512
# 4  female        group E        70.811594           75.840580
# 5    male        group A        63.735849           61.735849
# 6    male        group B        65.930233           62.848837
# 7    male        group C        67.611511           65.424460
# 8    male        group D        69.413534           66.135338
# 9    male        group E        76.746479           70.295775

# %%
df.math_score.unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8])

# %%
df.sort_values(['gender', 'math_score'], ascending=False).groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education          lunch  \
# 149    male        group E           associate's degree  free/reduced
# 623    male        group A                 some college      standard
# 625    male        group D                 some college      standard
# 916    male        group E            bachelor's degree      standard
# 306    male        group E                 some college      standard
# 451  female        group E                 some college      standard
# 458  female        group E            bachelor's degree      standard
# 962  female        group E           associate's degree      standard
# 114  female        group E            bachelor's degree      standard
# 263  female        group E                  high school      standard
#
#     test preparation course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
df['total_score'] = df.math_score + df.reading_score + df.writing_score

# %%
df.math_score + df.reading_score + df.writing_score
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education          lunch  \
# 0  female        group B            bachelor's degree      standard
# 1  female        group C                 some college      standard
# 2  female        group B              master's degree      standard
# 3    male        group A           associate's degree  free/reduced
# 4    male        group C                 some college      standard
#
#   test preparation course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df = df.assign(total_score_log = np.log(df.total_score))

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education          lunch  \
# 0  female        group B            bachelor's degree      standard
# 1  female        group C                 some college      standard
# 2  female        group B              master's degree      standard
# 3    male        group A           associate's degree  free/reduced
# 4    male        group C                 some college      standard
#
#   test preparation course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
df.drop(['total_score'], axis = 1)
# Out:
#      gender race/ethnicity parental_level_of_education          lunch  \
# 0    female        group B            bachelor's degree      standard
# 1    female        group C                 some college      standard
# 2    female        group B              master's degree      standard
# 3      male        group A           associate's degree  free/reduced
# 4      male        group C                 some college      standard
# ..      ...            ...                          ...           ...
# 995  female        group E              master's degree      standard
# 996    male        group C                  high school  free/reduced
# 997  female        group C                  high school  free/reduced
# 998  female        group D                 some college      standard
# 999  female        group D                 some college  free/reduced
#
#     test preparation course  math_score  reading_score  writing_score  \
# ...

# %%
nogi = pd.read_csv('/content/dota_hero_stats.csv')

# %%
#nogi.head()

# %%
#nogi.sort_values('legs')

# %%
#n = nogi.sort_values('legs', ascending=True).groupby('legs').count()

# %%
n = nogi.sort_values(['attack_type', 'primary_attr'], ascending=False)

# %%
n
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 57           57      Ranged   59     2          Huskar
# 89           89      Ranged   91     0              Io
# 108         108      Ranged  110     2         Phoenix
# 2             2      Ranged    3     4            Bane
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 91           91       Melee   93     2           Slark
# 104         104       Melee  106     2    Ember Spirit
# 107         107       Melee  109     2     Terrorblade
# 112         112       Melee  114     2     Monkey King
# 114         114       Melee  120     2       Pangolier
#
#                              name primary_attr  \
# 57           npc_dota_hero_huskar          str
# 89             npc_dota_hero_wisp          str
# 108         npc_dota_hero_phoenix          str
# 2              npc_dota_hero_bane          int
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
nogi.sort_values(['attack_type', 'primary_attr'], ascending=False).groupby(['attack_type', 'primary_attr']).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
zp = pd.read_csv('/content/accountancy.csv')

# %%
zp_1 = zp.sort_values('Type').groupby('Type').head()

# %%
zp_2 = zp_1.sort_values('Salary', ascending=False).groupby('Salary').head()

# %%
zp_2
# Out:
#     Unnamed: 0 Executor Type  Salary
# 6            6    Loopa    B     249
# 35          35    Loopa    F     244
# 19          19     Pupa    A     234
# 5            5    Loopa    F     232
# 37          37    Loopa    C     222
# 13          13     Pupa    A     217
# 7            7     Pupa    F     195
# 31          31     Pupa    D     185
# 43          43    Loopa    B     185
# 38          38    Loopa    D     181
# 40          40    Loopa    D     172
# 1            1     Pupa    A     158
# 20          20    Loopa    E     156
# 33          33     Pupa    F     146
# 45          45    Loopa    D     146
# 10          10    Loopa    C     145
# 48          48     Pupa    F     142
# 32          32    Loopa    B     128
# 36          36    Loopa    E     122
# 8            8     Pupa    A     115
# 3            3     Pupa    E     109
# 24          24     Pupa    C      94
# 18          18    Loopa    E      83
# 27          27    Loopa    C      81
# ...

# %%
res = (zp.groupby(['Type']).apply(lambda x: x.nlargest(1,['Salary'])))

# %%
res
# Out:
#          Unnamed: 0 Executor Type  Salary
# Type
# A    19          19     Pupa    A     234
# B    6            6    Loopa    B     249
# C    44          44    Loopa    C     249
# D    2            2     Pupa    D     194
# E    42          42    Loopa    E     220
# F    35          35    Loopa    F     244

# %%
concentrations = pd.read_csv('/content/algae.csv')

# %%
concentrations.head()
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
mean_concentrations = concentrations.groupby('genus').mean()

# %%
mean_concentrations
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
c = concentrations.sort_values('alanin', ascending=False)

# %%
c = np.around(concentrations.query("genus == 'Fucus'").alanin.describe().loc[['min', 'mean', 'max']].values, decimals=2)

# %%
c
# Out:
# array([0.35, 3.57, 6.64])

# %%
concentrations.groupby('genus').agg(['min', 'mean', 'max']).loc['Fucus', 'alanin'].round(2)
# Out:
# min     0.35
# mean    3.57
# max     6.64
# Name: Fucus, dtype: float64

# %%
concentrations.groupby('group').aggregate({'glucose': lambda x: max(x) - min(x) })
# Out:
#         glucose
# group
# brown  3.740495
# green  1.026753
# red    0.000000

# %% [markdown]
# ##1.7 Визуализация

# %%
df.math_score.hist()

# %%
df.plot.scatter(x='math_score', y='reading_score')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender', data=df, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
df = pd.read_csv('/content/income.csv')

# %%
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot(kind='line')

# %%
sns.lineplot(data=df)

# %%
df.plot()

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
plt.plot(df.index, df.income)

# %%
df.income.plot()

# %%
df['income'].plot()

# %%
df = pd.read_csv("dataset_209770_6.txt", sep=" ")

# %%
df
# Out:
#                x            y
# 0    1193.813813   307.892018
# 1    1198.780254   309.808551
# 2    1509.577605   578.207192
# 3     880.937564   699.004531
# 4    1485.651890   612.821381
# ..           ...          ...
# 105  1089.871826   409.920214
# 106  1205.612940   294.376152
# 107   888.871189   722.132361
# 108  1114.188091   392.873194
# 109   191.800522  1214.986450
#
# [110 rows x 2 columns]

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
df.plot.scatter(x='x', y='y')

# %%
df = pd.read_csv('/content/genome_matrix.csv', index_col = 0)

# %%
df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(data=df, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
data = pd.read_csv('/content/dota_hero_stats.csv')

# %%
data
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
lenths = [len(x.split(',')) for x in data.roles]
data['lenths'] = lenths

# %%
data['lenths'].mean()
# Out:
# 4.0

# %%
data = pd.read_csv('/content/iris.csv', index_col=0)

# %%
data
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.kdeplot(data=data)

# %%
sns.violinplot(data=data['petal length'])

# %%
sns.pairplot(data)

# %% [markdown]
# ##Практические задания

# %%
my_data = pd.DataFrame({'type':['A', 'A', 'B', 'B'], 'value':['10', '14', '12', '23']})
my_data['type'] = my_data['type'].astype(str)
my_data['value'] = my_data['value'].astype(int)

# %%
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
import pandas as pd
import numpy as np

# %%
my_stat = pd.read_csv('/content/my_stat.csv')

# %%
my_stat
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %% [markdown]
# В переменную с именем subset_1 сохраните только первые 10 строк и только 1 и 3 колонку.
# В переменную с именем subset_2 сохраните все строки кроме 1 и 5 и только 2 и 4 колонку.

# %%
subset_1 = my_stat.iloc[0:10, [0,2]]

# %%
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
subset_2 = my_stat.drop([0, 4]).iloc[:, [1,3]]

# %%
subset_2
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %% [markdown]
# В переменную subset_1 сохраните только те наблюдения, у которых значения переменной V1  строго больше 0, и значение переменной V3  равняется 'A'.
#
# В переменную  subset_2  сохраните только те наблюдения, у которых значения переменной V2  не равняются 10, или значения переменной V4 больше или равно 1.

# %%
subset_1 = my_stat.query('V1>0 & V3 == "A"')

# %%
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2 = my_stat.query('V2 != 10 | V4 >= 1')

# %%
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
my_stat['V5'] = my_stat[['V1','V4']].sum(axis=1)

# %%
my_stat
# Out:
#      V1    V2 V3   V4   V5
# 0     2  13.0  B  1.0  3.0
# 1    -1   7.0  B  1.0  0.0
# 2     0  11.0  A  0.0  0.0
# 3     2  11.0  A  2.0  4.0
# 4     0  10.0  B -1.0 -1.0
# ..   ..   ... ..  ...  ...
# 495   1   8.0  A -1.0  0.0
# 496   3   8.0  A  1.0  4.0
# 497  -1  11.0  B  2.0  1.0
# 498   1  11.0  A  2.0  3.0
# 499   0   8.0  B  1.0  1.0
#
# [500 rows x 5 columns]

# %%
my_stat['V6'] = np.log(my_stat['V2'])

# %%
my_stat
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# ..   ..   ... ..  ...  ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442
# 497  -1  11.0  B  2.0  1.0  2.397895
# 498   1  11.0  A  2.0  3.0  2.397895
# 499   0   8.0  B  1.0  1.0  2.079442
#
# [500 rows x 6 columns]

# %%
import pandas as pd
import numpy as np

# %%
my_stat = pd.read_csv('/content/my_stat_1.csv')

# %%
my_stat = my_stat.rename(columns={"V1": "session_value", "V2": "group", "V3": "time", "V4": "n_users"})

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
my_stat['session_value'] = my_stat['session_value'].fillna(0)

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
med = my_stat.query('n_users >= 0')['n_users'].median()
my_stat.loc[my_stat.n_users < 0, 'n_users'] = med

# %%
my_stat
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B        5
# 9            0.0     9     A        5

# %%
import pandas as pd
import numpy as np

# %%
my_stat = pd.read_csv('/content/my_stat.csv')

# %% [markdown]
# В этой задаче для данных my_stat рассчитайте среднее значение переменной session_value для каждой группы (переменная group), в получившемся dataframe  переменная group не должна превратиться в индекс. Также переименуйте колонку со средним значением session_value в mean_session_value.
#
# Получившийся результат сохраните в dataframe с именем mean_session_value_data.

# %%
my_stat = my_stat.rename(columns={"V1": "session_value", "V2": "time", "V3": "group", "V4": "n_users"})

# %%
my_stat
# Out:
#      session_value  time group  n_users
# 0                2  13.0     B      1.0
# 1               -1   7.0     B      1.0
# 2                0  11.0     A      0.0
# 3                2  11.0     A      2.0
# 4                0  10.0     B     -1.0
# ..             ...   ...   ...      ...
# 495              1   8.0     A     -1.0
# 496              3   8.0     A      1.0
# 497             -1  11.0     B      2.0
# 498              1  11.0     A      2.0
# 499              0   8.0     B      1.0
#
# [500 rows x 4 columns]

# %%
mean_session_value_data = my_stat.groupby('group', as_index=False).session_value.agg({'mean_session_value' : 'mean'})
